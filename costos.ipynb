# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_frame = pd.read_csv("costo.csv", header=None)
x = data_frame.to_numpy()
y = np.array([i for i in range(x.size)])

# %%
plt.title("Costos SNN")
plt.plot(y, x, color="red")
